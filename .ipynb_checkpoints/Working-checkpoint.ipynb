# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup as bs
import requests

# %%
url = "https://www.airlinequality.com/airline-reviews/british-airways/page/1/"
response = requests.get(url)
html_content = response.content

# %%
soup = bs(html_content, 'lxml')

# %%
article = soup.find(itemprop = 'review')

# %%
ratingValue =  int(article.find(itemprop = 'ratingValue').text)

# %%
ratingValue
# Out:
# 1

# %%
heading = str(article.find('h2', class_ = 'text_header').text)

# %%
h3 = article.find('h3').text

# %%
values = h3.split('(')

# %%
author = values[0]

# %%
country = values[1].split(')')[0]
timeline = values[1].split(')')[1]

# %%
author, country, timeline
# Out:
# ('\n\nD Baker ', 'United States', ' 6th June 2024')

# %%
verification = article.find(class_ = 'text_content').find('em').text

# %%
verification
# Out:
# 'Trip Verified'

# %%
contents = article.find(class_ = 'text_content').text

# %%
contents.split('|')
# Out:
# ['✅ Trip Verified ',
# ...

# %%
content = contents.split('|')[1]

# %%
table = article.find('table', class_ = 'review-ratings')

# %%
table
# Out:
# <table class="review-ratings">
# <tr><td class="review-rating-header aircraft">Aircraft</td><td class="review-value">Boeing 747</td></tr>
# <tr><td class="review-rating-header type_of_traveller">Type Of Traveller</td><td class="review-value">Business</td></tr>
# <tr><td class="review-rating-header cabin_flown">Seat Type</td><td class="review-value">Business Class</td></tr>
# <tr><td class="review-rating-header route">Route</td><td class="review-value">Heathrow to San Francisco</td></tr>
# <tr><td class="review-rating-header date_flown">Date Flown</td><td class="review-value">June 2024</td></tr>
# <tr>
# <td class="review-rating-header seat_comfort">Seat Comfort</td>
# <td class="review-rating-stars stars"><span class="star fill">1</span><span class="star">2</span><span class="star">3</span><span class="star">4</span><span class="star">5</span></td>
# </tr>
# <tr>
# <td class="review-rating-header cabin_staff_service">Cabin Staff Service</td>
# ...

# %%
table.find('td', class_ = 'review-rating-header aircraft').find_next_sibling().text
# Out:
# 'Boeing 747'

# %%
table.find('td', class_ = 'review-rating-header seat_comfort').find_next_sibling().find(class_ = 'fill').text
# Out:
# '1'

# %%
i = 1
for tr in x:
    for td in tr:
        if i<6:
            print(td.text)
    i +=1
    if i>5:
        if i==6:
            i+=1
            continue
        elif i>14:
            print(tr.find(class_ = 'rating-no').text)
        else:
            print(tr.find('span', class_ = 'fill').text)
            print(i)
        i+=1
# Out:
# Aircraft
# Boeing 747
# Type Of Traveller
# Business
# Seat Type
# Business Class
# Route
# Heathrow to San Francisco
# Date Flown
# June 2024
# 1
# 8
# 1
# 10
# 1
# 12
# 1
# 14
# no

# %%
ratingValues = []
headings = []
authors = []
countries = []
timelines = []
verifications = []
contentss = []
aircraft = []
type_of_travellers = []
seat_type = []
route = []
date_flown = []
seat_comfort = []
cabin_staff_service	= []
ground_service = []
value_for_money = []
recommended = []
food_and_beverages = []
inflight_entertainment = []
wifi_connectivity = []



def fetch_article(page_no):
    url = f"https://www.airlinequality.com/airline-reviews/british-airways/page/{page_no}/"
    response = requests.get(url)
    html_content = response.content

    soup = bs(html_content, 'lxml')
    articles = soup.find_all(itemprop = 'review')

    for article in articles:
        try:
            ratingValue =  int(article.find(itemprop = 'ratingValue').text)    
            ratingValues.append(ratingValue)
        except:
            ratingValues.append(None)

        try:
            heading = str(article.find('h2', class_ = 'text_header').text)
            headings.append(heading)
        except:
            headings.append(None)

        h3 = article.find('h3').text
        values = h3.split('(')
        
        try:
            author = values[0]
            authors.append(author)
        except:
            authors.append(None)

        try:
            country = values[1].split(')')[0]
            countries.append(country)
        except:
            countries.append(None)
            
        try:
            timeline = values[1].split(')')[1]
            timelines.append(timeline)
        except:
            timelines.append(None)
        

        try:
            verification = article.find(class_ = 'text_content').find('em').text
            verifications.append(verification)
        except:
            verifications.append(None)

        try:
            contents = article.find(class_ = 'text_content').text
            content = contents.split('|')[1]
            contentss.append(content)
        except:
            contentss.append(None)
        
        table = article.find('table', class_ = 'review-ratings')
    
    
        try:
            val = table.find('td', class_ = 'review-rating-header aircraft').find_next_sibling().text
            aircraft.append(val)
        except:
            aircraft.append(None)

        try:
            val = table.find('td', class_ = 'review-rating-header type_of_traveller').find_next_sibling().text
            type_of_travellers.append(val)
        except:
            type_of_travellers.append(None)

        try:
            val = table.find('td', class_ = 'review-rating-header cabin_flown').find_next_sibling().text
            seat_type.append(val)
        except:
            seat_type.append(None)
        
        try:
            val = table.find('td', class_ = 'review-rating-header route').find_next_sibling().text
            route.append(val)
        except:
            route.append(None)
        
        try:  
            val = table.find('td', class_ = 'review-rating-header date_flown').find_next_sibling().text
            date_flown.append(val)
        except:
            date_flown.append(None)


        try:
            val = table.find('td', class_ = 'review-rating-header recommended').find_next_sibling().text
            recommended.append(val)
        except:
            recommended.append(None)

        
        try:    
            val = table.find('td', class_ = 'review-rating-header seat_comfort').find_next_sibling().find(class_ = 'fill').text
            seat_comfort.append(int(val))
        except:
            seat_comfort.append(None)
        
        try:
            val = table.find('td', class_ = 'review-rating-header cabin_staff_service').find_next_sibling().find(class_ = 'fill').text
            cabin_staff_service.append(int(val))
        except:
            cabin_staff_service.append(None)
        
        try:
            val = table.find('td', class_ = 'review-rating-header ground_service').find_next_sibling().find(class_ = 'fill').text
            ground_service.append(int(val))
        except:
            ground_service.append(None)
        
        try:
            val = table.find('td', class_ = 'review-rating-header value_for_money').find_next_sibling().find(class_ = 'fill').text
            value_for_money.append(int(val))
        except:
            value_for_money.append(None)
        

        try:
            val = table.find('td', class_ = 'review-rating-header inflight_entertainment').find_next_sibling().find(class_ = 'fill').text
            inflight_entertainment.append(int(val))
        except:
            inflight_entertainment.append(None)


        try:
            val = table.find('td', class_ = 'review-rating-header wifi_and_connectivity').find_next_sibling().find(class_ = 'fill').text
            wifi_connectivity.append(int(val))
        except:
            wifi_connectivity.append(None)


        try:
            val = table.find('td', class_ = 'review-rating-header food_and_beverages').find_next_sibling().find(class_ = 'fill').text
            food_and_beverages.append(int(val))
        except:
            food_and_beverages.append(None)

# %%
# %%time
for i in range(1,382): 
    fetch_article(i)
# Out:
# CPU times: total: 2min 44s
# Wall time: 19min 12s

# %%
ratingValues, headings,authors,countries,timelines,verifications,contentss,aircraft,type_of_travellers,seat_type,route ,date_flown,seat_comfort,cabin_staff_service,ground_service,value_for_money,recommended,food_and_beverages,inflight_entertainment,wifi_connectivity
# Out:
# ([1,
#   5,
#   1,
#   9,
#   2,
#   1,
#   1,
#   2,
#   3,
#   3,
#   9,
#   3,
#   2,
#   1,
#   4,
#   2,
#   6,
#   1,
#   1,
#   1,
#   1,
#   1,
#   6,
#   1,
#   1,
#   10,
#   7,
#   3,
#   4,
#   8,
#   1,
#   8,
#   5,
#   10,
#   9,
#   3,
#   8,
#   8,
#   3,
#   3,
#   7,
#   3,
#   1,
#   7,
#   1,
#   3,
#   1,
#   1,
#   3,
#   10],
#  ['“never fly British Airways"',
#   '“we will rethink BA moving forward”',
#   '“extremely poor customer service”',
#   '“a pleasant and civilized journey”',
#   '"the worst BA flight we\'ve experienced"',
#   '"Never again British Airways"',
#   '"only been offered half a glass of water"',
#   '"told by cabin crew I would be refunded"',
#   '“premium price for a sub-par product”',
#   '"can\'t even choose my own seat"',
#   '“Very impressed with BA”',
#   '"appalling customer service"',
#   '"baggage customer service is a joke"',
#   '"Worst business class ever"',
#   '"replicating the likes of Ryanair"',
# ...

# %%
x
# Out:
# [1]

# %%
print(None)
# Out:
# None

# %%
table.find('td', class_ = 'review-rating-header recommended').find_next_sibling().text
# Out:
# 'no'

# %%
df = pd.DataFrame()

# %%
df['Heading'] = headings
df['RatingValue'] = ratingValues
df['Author'] = authors
df['Country'] = countries
df['Timeline'] = timelines
df['Verification'] = verifications
df['Content'] = contentss
df['Aircraft'] = aircraft
df['Type_of_traveller'] = type_of_travellers
df['SeatType'] = seat_type
df['Route'] = route
df['DateFlown'] = date_flown
df['SeatComfort'] = seat_comfort
df['CabinStaffService'] = cabin_staff_service
df['GroundService'] = ground_service
df['ValueForMoney'] = value_for_money
df['Recommend'] = recommended
df['FoodBeverages'] = food_and_beverages
df['InflightEntertainment'] = inflight_entertainment
df['WifiConnectivity'] = wifi_connectivity

# %%
df.shape
# Out:
# (3807, 20)

# %%
df.to_csv('British_Airways.csv', header=True, index=False)

# %%
data = pd.read_csv('British_Airways.csv')

# %%
data
# Out:
#                                       Heading  RatingValue  \
# 0                 “never fly British Airways"          1.0
# 1         “we will rethink BA moving forward”          5.0
# 2           “extremely poor customer service”          1.0
# 3          “a pleasant and civilized journey”          9.0
# 4     "the worst BA flight we've experienced"          2.0
# ...                                       ...          ...
# 3802          British Airways customer review          1.0
# 3803          British Airways customer review          9.0
# 3804          British Airways customer review          5.0
# 3805          British Airways customer review          4.0
# 3806          British Airways customer review          4.0
#
#                      Author         Country            Timeline  \
# 0              \n\nD Baker    United States       6th June 2024
# 1             \n\nVal Rose   United Kingdom       3rd June 2024
# ...
